# %%
import seaborn as sns

points = {
    'Skewness': [0, 0, 2, -.1],
    'Kurtosis': [0, -.5, 6, -.2],
    'Distribution': ['gaussian', 'exponential', 'uniform', 'processed data'],
}

# %%
sns.set(rc={'savefig.dpi': 300})
output_folder = 'output'
plot = sns.scatterplot(points, x='Skewness', y='Kurtosis', hue='Distribution')
# fig = plot.fig
# fig.title('Skewness and Kurtosis in 2D space')
plot.figure.savefig('skewness_kurtosis.png')
